# %%
import requests
from bs4 import BeautifulSoup

# %%
res=requests.get("http://www.104.com.tw/i/apis/jobsearch.cfm?kws=bigdata&kwop=2&area=6001001000,6001002000&cat=2007001000&role=1")
soup=BeautifulSoup(res.text, "html5lib")
for item in soup.select('.content'):
    print(item)
# Out:
# <div class="content"><div><dt>專案工程師．台北市松山區</dt>
# 	<div class="dLn">程曦資訊整合股份有限公司</div>
# 	<div class="dList">
# 		<div>專科，2年，薪資面議</div>
# 		<div>2016年組織擴編，除原有專案團隊外，另成立數據服務部門等相關新事業單位，拓展原有事業體系(金融產品、CRM產品之專案與產品研發單位)、新事業單位(Big Data)之部門與發展，因此大舉招募具有Java開發能力、數據分析(資料庫探勘data mining)等專才，進行前台、後台之web系統，研發、客製化開發之工作，按照開發組長SD、SA專案客戶的規範來開發程式，定期回報進度與開發問題。 【專案部門】 *執行國內金融及企業客戶IVR、CSR及CRM專案軟體上線、測試與修改。 *需開發IVR、CSR系統及Web之程式。 *學習與參與CMMI ML4專案品管流程，與外部客戶會有互動。(前後端開發研發) *系統設計，並撰寫程式設計規格文件及系統專案文件 *使用者教育訓練及系統維護</div>
#
# 			<div class="txt_gray"><span class="float_R">
# 			</span>更新時間： 暫無人應徵，立即搶先機！</div>
#
# 	</div>
# 	</div>
# 	<div><dt>BigData 分析工程師．台北市中正區</dt>
# 	<div class="dLn">德義資訊股份有限公司</div>
# 	<div class="dList">
# 		<div>大學（學院），2年，薪資面議</div>
# ...

# %%
.select('dt')[0].text,item.select('.dLn')[0].text,item.select('.dList')[0].text
# Out:
# bs4.BeautifulSoup

# %%
requests.__file__
# Out:
# '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/__init__.py'
